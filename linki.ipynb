# %% [markdown]
# Polskie materiały w sieci
#
# - https://wazniak.mimuw.edu.pl/index.php?title=Rachunek_prawdopodobie%C5%84stwa_i_statystyka
# - https://wazniak.mimuw.edu.pl/index.php?title=Rachunek_Prawdopodobie%C5%84stwa_i_Statystyka_(UW)

# %% [markdown]
# Polska książka (sporo matematyki)
#
# ![image.png](attachment:041fcbae-ccab-4f3f-9721-cdc3db8f25cf.png) $\quad$ ![image.png](attachment:149356c5-3eb5-45bc-b3ce-59ca75ccb2f9.png)
#
# Lekka, popularnonaukowo książka
#
# ![image.png](attachment:b4b01bd6-417e-4d05-ba2a-1b23db9ee1e6.png)

# %% [markdown]
# ### Harvard: Statistics 110: Probability
#
# Wykłady ze statystyki i prawodopodobieństwa na Harvardzie:
#
# https://projects.iq.harvard.edu/stat110/home
#
# książka z wykładów: https://drive.google.com/file/d/1VmkAAGOYCTORq1wxSQqy255qLJjTNvBI/edit
#
# i wykłady na youtubie: https://www.youtube.com/playlist?list=PL2SOU6wwxB0uwwH80KTQ6ht66KWxbzTIo

# %% [markdown]
# Kanały na youtubie warte spojrzenia:
# - https://www.youtube.com/@statquest
# - https://www.youtube.com/@3blue1brown
# - https://www.youtube.com/playlist?list=PLIhj5_pQwhMQfGZNQZREjDdJRt0t0sn51

# %% [markdown]
# KhanAcademy
#
# https://pl.khanacademy.org/math/probability

# %% [markdown]
# ### 5. Wykres punktowy

# %% [markdown]
# Tło: \
# W pliku `stock_prices.csv` znajdują się ceny zamknięcia akcji Apple, Alphabet Inc. (Google) oraz Bank of America w różnych dniach na przestrzeni 6 miesięcy.
#
# Zadanie 1: \
# Utwórz wykres punktowy przedstawiający ceny akcji Apple i Alphabet.
#
# Zadanie 2: \
# Utwórz wykres punktowy przedstawiający ceny akcji Apple i Bank of America.
#
# Zadanie 3: \
# Zbadaj, czy istnieje zależność między tymi zmiennymi.

# %%
import pandas as pd

# Wczytanie pliku CSV (serparatorem csvki jest średnik,
# a przecinek jest separatorem dziesiętnym)
df = pd.read_csv(
    "stock_prices.csv", 
    sep=";", 
    decimal=','
)
df
# Out:
#           Date  Apple (AAPL)  Alphabet (GOOGL)  Bank of America (BAC)
# 0     3-1-2017        116.15            808.01                  22.53
# 1     4-1-2017        116.02            807.77                  22.95
# 2     5-1-2017        116.61            813.02                  22.68
# 3     6-1-2017        117.91            825.21                  22.68
# 4     9-1-2017        118.99            827.18                  22.55
# ..         ...           ...               ...                    ...
# 99   25-5-2017        153.87            991.86                  23.25
# 100  26-5-2017        153.61            993.27                  23.24
# 101  30-5-2017        153.67            996.17                  22.91
# 102  31-5-2017        152.76            987.09                  22.41
# 103   1-6-2017        153.18            988.29                  22.63
#
# [104 rows x 4 columns]

# %%
# Zadanie 1
df.plot(kind='scatter', x='Apple (AAPL)', y='Alphabet (GOOGL)')
# Out:
# <Axes: xlabel='Apple (AAPL)', ylabel='Alphabet (GOOGL)'>

# %%
# Zadanie 2
df.plot(kind='scatter', x='Apple (AAPL)', y='Bank of America (BAC)')
# Out:
# <Axes: xlabel='Apple (AAPL)', ylabel='Bank of America (BAC)'>

# %% [markdown]
# Zadanie 3
#
# Na podstawie oceny wizualnej można łatwo zauważyć, że wartości akcji `Apple (AAPL)` i `Alphabet (GOOGL)` są ze sobą skorelowane (jak jedne rosną to drugie też) podczas gdy wartości akcji `Apple (AAPL)` i `Bank of America (BAC)` nie.
